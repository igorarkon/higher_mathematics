# %% [markdown]
# # 1 Задание (теорема сложения)

# %% [markdown]
# Найти вероятность выпадения 2 или 5 очков при подбрасывании игральной кости, на гранях которой имеются соответственно 1,2,3,4,5 и 6 очков.

# %% [markdown]
# Вероятность находится по формуле P = m/n
#
# m - число необходимых исходов
#
# n - число всех исходов

# %% [markdown]
# Вероятность выпадения 2 очков = 1/6
#
# Вероятность выпадения 5 очков = 1/6
#
# Вероятность выпадения 2 или 5 очка = 2/6

# %% [markdown]
# # 2 Задание (теорема умножения)

# %% [markdown]
# Найти вероятность того, что при двух подбрасываниях той же самой игральной кости сначала выпадет 2, а затем 5.

# %% [markdown]
# Для вычисления двух подряд исходов, вероятности умножаются
#
# 1/6 * 1/6 = 1/36

# %% [markdown]
# # 3 Задание

# %% [markdown]
#
# Найти вероятность выпадения 2 и 5 очков при двух подбрасываниях той же самой игральной игральной кости. Обратите внимание на порядок выпадения костей!

# %% [markdown]
# В данном случае порядок не важен, то есть возможно как 2 и 5, так и 5 и 2, тогда:
#
# 2 * 1/36 = 1/18

# %% [markdown]
# # 4 Задание  (Геометрическая вероятность +интервалы)

# %% [markdown]
# На отрезке AB длиной 20 см наугад отметили точку C. Какова вероятность, что она находится на расстоянии не более 9 см от точки А и не более 15 см от точки В?

# %% [markdown]
# Согласно условию задачи точка А это 0, а точка В это 20, тогда необходимый исход расположен от 0 до 9 и при этом от 5 до 15.
#
# Тогда необходимый интервал есть пересечение от 5 до 9 и равен 4
#
# Общая вероятность равна 1/20
#
# Вероятность выпадения точки по условию задачи 4 * 1/20 = 1/5

# %% [markdown]
# # 5 Задание

# %% [markdown]
# Телефонный номер состоит из 7 цифр. Какова вероятность, что это номер 8882227?

# %% [markdown]
# Номер моет состоять от 0 до 9, соответственно семь цифр имеют 10**7 вариантов исходов
#
# Благоприятный исход один, тогда вероятность = 1/10**7

# %% [markdown]
# # 6 Задание

# %% [markdown]
# Набирая номер телефона, абонент забыл 2 последние цифры, и, помня только то, что эти цифры различны и среди них нет нуля, стал набирать их наудачу. Сколько вариантов ему надо перебрать, чтобы наверняка найти нужный номер? Какова вероятность того, что он угадает номер с первого раза?

# %% [markdown]
# Номер возможен от 1 до 9 и приэтом не повторяется, тогда вариаций 8*8 = 64
#
# Необходимый исход 1, тогда вероятность с первого раза набрать = 1/64
